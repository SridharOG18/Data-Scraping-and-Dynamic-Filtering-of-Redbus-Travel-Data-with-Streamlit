# %%
import pandas as pd
from sqlalchemy import create_engine

# %%
csv_file_path = r'C:\Users\sridhar M\Downloads\scraping\combined_final_clean_file.csv'  # Replace with your CSV file path
df = pd.read_csv(csv_file_path)

# %%
df
# Out:
#                                                Bus_name  \
# 0     Assam State Transport Corporation (ASTC) - 157959
# 1     Assam State Transport Corporation (ASTC) - 154930
# 2     Assam State Transport Corporation (ASTC) - 161055
# 3                                  Chartered Bus - ASTC
# 4                                  Chartered Bus - ASTC
# ...                                                 ...
# 2282                                 Gogol City Service
# 2283                                 Gogol City Service
# 2284                                    Satadal Travels
# 2285                               Diamond City Service
# 2286                                 Droupadi Paribahan
#
#                                               Bus_type Start_time  End_time  \
# 0                         Bharat Benz A/C Seater (2+2)      14:00     18:30
# 1                                  Volvo AC Seater 2+2      15:45     20:00
# ...

# %%
database_url = 'mysql+pymysql://root:Sridhar71801@localhost/rbus'
# Create a database engine
engine = create_engine(database_url)

# %%
# Use 'to_sql' to create a new table and insert the data
df.to_sql('bus_routes', con=engine, if_exists='replace', index=False)
# Out:
# 2287

# %%
query = "SELECT * FROM bus_routes;"
result_df = pd.read_sql_query(query, con=engine)
result_df
# Out:
#                                                Bus_name  \
# 0     Assam State Transport Corporation (ASTC) - 157959
# 1     Assam State Transport Corporation (ASTC) - 154930
# 2     Assam State Transport Corporation (ASTC) - 161055
# 3                                  Chartered Bus - ASTC
# 4                                  Chartered Bus - ASTC
# ...                                                 ...
# 2282                                 Gogol City Service
# 2283                                 Gogol City Service
# 2284                                    Satadal Travels
# 2285                               Diamond City Service
# 2286                                 Droupadi Paribahan
#
#                                               Bus_type Start_time  End_time  \
# 0                         Bharat Benz A/C Seater (2+2)      14:00     18:30
# 1                                  Volvo AC Seater 2+2      15:45     20:00
# ...

# %%
import pymysql

# %%
connection = pymysql.connect(host='127.0.0.1', user='root', password='Sridhar71801', database='rbus')

# %%
cursor = connection.cursor()

# %%
cursor.execute("USE rbus")
# Out:
# 0

# %%
cursor.execute("SELECT * FROM bus_routes")
results = cursor.fetchall()

# %%
for row in results:
    print(row)
# Out:
# ('Assam State Transport Corporation (ASTC) - 157959', 'Bharat Benz A/C Seater (2+2)', '14:00', '18:30', '04h 30m', 'INR98', '22 Seats available', 4.2, 'https://www.redbus.in/bus-tickets/tezpur-to-guwahati', 'Tezpur to Guwahati')
# ('Assam State Transport Corporation (ASTC) - 154930', 'Volvo AC Seater 2+2', '15:45', '20:00', '04h 15m', 'INR98', '27 Seats available', 3.7, 'https://www.redbus.in/bus-tickets/tezpur-to-guwahati', 'Tezpur to Guwahati')
# ('Assam State Transport Corporation (ASTC) - 161055', 'Volvo AC Seater 2+2', '16:15', '20:30', '04h 15m', 'INR98', '24 Seats available', 4.2, 'https://www.redbus.in/bus-tickets/tezpur-to-guwahati', 'Tezpur to Guwahati')
# ('Chartered Bus - ASTC', 'A/C Seater Push Back (2+2)', '11:30', '16:15', '04h 45m', 'INR34.68', '2 Seats available', 4.0, 'https://www.redbus.in/bus-tickets/tezpur-to-guwahati', 'Tezpur to Guwahati')
# ...

# %%
for i in range(len(df)):
    connection.cursor().execute(f"insert into rbus.bus_routes value{tuple(df.iloc[i])}")
    connection.commit

# %%
for i in range(len(df)):
    print(df.iloc[i])
# Out:
# Bus_name           Assam State Transport Corporation (ASTC) - 157959
# Bus_type                                Bharat Benz A/C Seater (2+2)
# Start_time                                                     14:00
# End_time                                                       18:30
# Total_duration                                               04h 30m
# Price                                                          298.0
# Seats_Available                                   22 Seats available
# Ratings                                                          4.2
# Route_link         https://www.redbus.in/bus-tickets/tezpur-to-gu...
# Route_name                                        Tezpur to Guwahati
# Name: 0, dtype: object
# Bus_name           Assam State Transport Corporation (ASTC) - 154930
# Bus_type                                         Volvo AC Seater 2+2
# Start_time                                                     15:45
# ...

# %%
df
# Out:
#                                                Bus_name  \
# 0     Assam State Transport Corporation (ASTC) - 157959
# 1     Assam State Transport Corporation (ASTC) - 154930
# 2     Assam State Transport Corporation (ASTC) - 161055
# 3                                  Chartered Bus - ASTC
# 4                                  Chartered Bus - ASTC
# ...                                                 ...
# 2282                                 Gogol City Service
# 2283                                 Gogol City Service
# 2284                                    Satadal Travels
# 2285                               Diamond City Service
# 2286                                 Droupadi Paribahan
#
#                                               Bus_type Start_time  End_time  \
# 0                         Bharat Benz A/C Seater (2+2)      14:00     18:30
# 1                                  Volvo AC Seater 2+2      15:45     20:00
# ...

# %%
connection.commit()
